# %% [markdown]
# # chapter 1

# %% [markdown]
# ## lesson 1.3 Pands Overview

# %%
import pandas as pd

# %%
# load data
my_data = pd.read_csv("drinks.csv")

# %%
# pretty printing
my_data
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol
# 0                             0.0
# 1                             4.9
# 2                             0.7
# 3                            12.4
# ...

# %%
# top 10 rows
my_data.head(10)
# Out:
#              country  beer_servings  spirit_servings  wine_servings  \
# 0        Afghanistan              0                0              0
# 1            Albania             89              132             54
# 2            Algeria             25                0             14
# 3            Andorra            245              138            312
# 4             Angola            217               57             45
# 5  Antigua & Barbuda            102              128             45
# 6          Argentina            193               25            221
# 7            Armenia             21              179             11
# 8          Australia            261               72            212
# 9            Austria            279               75            191
#
#    total_litres_of_pure_alcohol
# 0                           0.0
# 1                           4.9
# 2                           0.7
# 3                          12.4
# 4                           5.9
# ...

# %%
# last 10 rows
my_data.tail(10)
# Out:
#         country  beer_servings  spirit_servings  wine_servings  \
# 183    Tanzania             36                6              1
# 184         USA            249              158             84
# 185     Uruguay            115               35            220
# 186  Uzbekistan             25              101              8
# 187     Vanuatu             21               18             11
# 188   Venezuela            333              100              3
# 189     Vietnam            111                2              1
# 190       Yemen              6                0              0
# 191      Zambia             32               19              4
# 192    Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol
# 183                           5.7
# 184                           8.7
# 185                           6.6
# 186                           2.4
# 187                           0.9
# 188                           7.7
# ...

# %%
# series vs. dataframe
print(type(my_data.country))
# Out:
# <class 'pandas.core.series.Series'>

# %%
# series vs. dataframe
print(type(my_data['country']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
print(type(my_data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# Selecting
my_data[booze.country == 'Canada']
# Out:
#    country  beer_servings  spirit_servings  wine_servings  \
# 32  Canada            240              122            100
#
#     total_litres_of_pure_alcohol
# 32                           8.2

# %%
# Sorting
my_data.sort_values(by='beer_servings')
# Out:
#             country  beer_servings  spirit_servings  wine_servings  \
# 0       Afghanistan              0                0              0
# 40     Cook Islands              0              254             74
# 79             Iran              0                0              0
# 90           Kuwait              0                0              0
# 97            Libya              0                0              0
# ..              ...            ...              ...            ...
# 135          Poland            343              215             56
# 65          Germany            346              117            175
# 62            Gabon            347               98             59
# 45   Czech Republic            361              170            134
# 117         Namibia            376                3              1
#
#      total_litres_of_pure_alcohol
# 0                             0.0
# 40                            5.9
# 79                            0.0
# ...

# %%
# Automatic statistics w/ describe()
my_data.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000
